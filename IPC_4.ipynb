# %% [markdown]
# <a href="https://colab.research.google.com/github/rockbmw3/Data-Analytics-py/blob/main/IPC_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Value": [56, 78, 90, 45, 88, 76, 65, 92, 81, 70],
    "Choice": ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B']
}

df = pd.DataFrame(data)
df.head(10)  # Task 2: Output first 10 rows
# Out:
#     ID  Value Choice
# 0  101     56      A
# 1  102     78      B
# 2  103     90      A
# 3  104     45      B
# 4  105     88      A
# 5  106     76      B
# 6  107     65      A
# 7  108     92      B
# 8  109     81      A
# 9  110     70      B

# %%
print(df["Value"])
# Out:
# 0    56
# 1    78
# 2    90
# 3    45
# 4    88
# 5    76
# 6    65
# 7    92
# 8    81
# 9    70
# Name: Value, dtype: int64

# %%
df.columns = ["ID number", "Random value", "Choice"]
df.head(5)
# Out:
#    ID number  Random value Choice
# 0        101            56      A
# 1        102            78      B
# 2        103            90      A
# 3        104            45      B
# 4        105            88      A

# %%
# Optional: Set display options for wider DataFrames
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Creating the DataFrame
student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'VI', 'V', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth': ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 13, 13, 14, 12, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 31, 32, 31],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
}, index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])

# Print original data
print("Original DataFrame:")
print(student_data)

# Group the data by 'school_code' and 'class'
print("\nSplit the said data on school_code, class wise:")
result = student_data.groupby(['school_code', 'class'])

# Loop through groups and print
for name, group in result:
    print("\nGroup:")
    print(name)
    print(group)
# Out:
# Original DataFrame:
#    school_code class            name date_Of_Birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
# S2        s002    VI    Gino Mcneill    17/05/2002   13     192      32
# S3        s003     V     Ryan Parkes    16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton    25/09/1998   14     167      31
# S5        s002     V    Gino Mcneill    11/05/2002   12     151      32
# S6        s004    VI    David Parkes    15/09/1997   12     159      31
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4
#
# Split the said data on school_code, class wise:
#
# Group:
# ('s001', 'V')
#    school_code class            name date_Of_Birth  age  height  weight  \
# S1        s001     V  Alberto Franco    15/05/2002   12     173      35
#
#     address
# S1  street1
#
# Group:
# ('s001', 'VI')
# ...

# %%
from google.colab import files
uploaded = files.upload()


df = pd.read_csv('data.csv')
df.head()
# Out:
#      <input type="file" id="files-17e112f9-1c40-4ba3-9c86-69187cebee55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17e112f9-1c40-4ba3-9c86-69187cebee55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
print(df.isnull().sum())  # Check nulls

# Replace with mean
df.fillna(df.mean(numeric_only=True), inplace=True)
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
print(df[['Calories', 'Pulse']].agg(['min', 'max', 'count', 'mean']))
# Out:
#           Calories       Pulse
# min      50.300000   80.000000
# max    1860.400000  159.000000
# count   169.000000  169.000000
# mean    375.790244  107.461538

# %%
filtered_df2 = df[(df['Calories'] > 500) & (df['Pulse'] < 100)]
filtered_df2
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = df.drop(columns=['Maxpulse'])
df_modified.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %%
df.drop(columns=['Maxpulse'], inplace=True)
df.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %%
df['Calories'] = df['Calories'].astype(int)
df.dtypes
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
plt.scatter(df['Duration'], df['Calories'], color='blue')
plt.title('Duration vs Calories')
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.grid(True)
plt.show()
